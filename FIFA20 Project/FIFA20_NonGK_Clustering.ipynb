# %% [markdown]
# # Author
#
# 1. Muhammad Dhiaz Rafilianza **(First Author)**
# 2. Ghazali Akmal Rabbani **(Second Author)**
# 3. Daniel Najoan **(Third Author)**

# %% [markdown]
# # Import Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('DataFrameTeamPositionNonGK_AllClub.csv')

# %%
df
# Out:
#        Unnamed: 0  sofifa_id  ...   rcb    rb
# 0               0     158023  ...  52+2  63+2
# 1               1      20801  ...  53+3  61+3
# 2               2     190871  ...  46+3  61+3
# 3               4     183277  ...  49+3  61+3
# 4               5     192985  ...  66+3  73+3
# ...           ...        ...  ...   ...   ...
# 13685       15312     251749  ...  49+2  55+2
# 13686       15314     251724  ...  54+2  56+2
# 13687       15315     251735  ...  57+2  57+2
# 13688       15316     251745  ...  61+2  61+2
# 13689       15319     251750  ...  57+2  57+2
#
# [13690 rows x 105 columns]

# %% [markdown]
# ## Dataframe Based On Physique

# %%
physic = df[['age','height_cm','weight_kg','overall','potential','preferred_foot','weak_foot','body_type','player_traits']]

# %%
physic.head()
# Out:
#    age  ...                                      player_traits
# 0   32  ...  Beat Offside Trap, Argues with Officials, Earl...
# 1   34  ...  Long Throw-in, Selfish, Argues with Officials,...
# 2   27  ...  Power Free-Kick, Injury Free, Selfish, Early C...
# 3   28  ...  Beat Offside Trap, Selfish, Finesse Shot, Spee...
# 4   28  ...  Power Free-Kick, Avoids Using Weaker Foot, Div...
#
# [5 rows x 9 columns]

# %%
le = LabelEncoder()
physic['preferred_foot'] = le.fit_transform(physic['preferred_foot'])
physic['body_type']      = le.fit_transform(physic['body_type'])
physic['player_traits']  = df.player_traits.str.count(',')
physic.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
physical = pd.DataFrame(physic.mean(axis=1),columns=['average physical skill'])
physical
# Out:
#        average physical skill
# 0                   52.888889
# 1                   55.666667
# 2                   52.111111
# 3                   52.555556
# 4                   53.000000
# ...                       ...
# 13685               43.444444
# 13686               44.333333
# 13687               50.625000
# 13688               49.875000
# 13689               51.000000
#
# [13690 rows x 1 columns]

# %% [markdown]
# ## DataFrame Based on General Stats

# %%
df_gen = df.iloc[:,32:38]
df_gen = df_gen.fillna(0)
df_gen['average general skill']=df_gen.mean(axis=1)
df_gen
# Out:
#        pace  shooting  passing  ...  defending  physic  average general skill
# 0      87.0      92.0     92.0  ...       39.0    66.0              78.666667
# 1      90.0      93.0     82.0  ...       35.0    78.0              77.833333
# 2      91.0      85.0     87.0  ...       32.0    58.0              74.666667
# 3      91.0      83.0     86.0  ...       35.0    66.0              75.833333
# 4      76.0      86.0     92.0  ...       61.0    78.0              79.833333
# ...     ...       ...      ...  ...        ...     ...                    ...
# 13685  77.0      53.0     57.0  ...       48.0    50.0              57.500000
# 13686  69.0      52.0     53.0  ...       54.0    59.0              57.833333
# 13687  72.0      30.0     49.0  ...       54.0    71.0              55.500000
# 13688  68.0      47.0     57.0  ...       59.0    68.0              59.000000
# 13689  67.0      50.0     50.0  ...       56.0    69.0              57.666667
#
# [13690 rows x 7 columns]

# %%
general =df_gen[['average general skill']]
general
# Out:
#        average general skill
# 0                  78.666667
# 1                  77.833333
# 2                  74.666667
# 3                  75.833333
# 4                  79.833333
# ...                      ...
# 13685              57.500000
# 13686              57.833333
# 13687              55.500000
# 13688              59.000000
# 13689              57.666667
#
# [13690 rows x 1 columns]

# %% [markdown]
# ## DataFrame Based On Attacking

# %%
df_attack = df.iloc[:,45:50]
df_attack = df_attack.fillna(0)
df_attack['average attacking skill']=df_attack.mean(axis=1)
attack = df_attack[['average attacking skill']]
attack
# Out:
#        average attacking skill
# 0                         86.6
# 1                         87.4
# 2                         82.0
# 3                         79.6
# 4                         80.8
# ...                        ...
# 13685                     53.6
# 13686                     50.6
# 13687                     43.8
# 13688                     52.2
# 13689                     49.8
#
# [13690 rows x 1 columns]

# %% [markdown]
# ## DataFrame Based on Skill

# %%
df_skill = df.iloc[:,50:55]
df_skill = df_skill.fillna(0)
df_skill['average controling skill']=df_skill.mean(axis=1)
skill = df_skill[['average controling skill']]
skill
# Out:
#        average controling skill
# 0                          94.4
# 1                          83.0
# 2                          89.4
# 3                          86.8
# 4                          87.2
# ...                         ...
# 13685                      57.8
# 13686                      55.2
# 13687                      46.4
# 13688                      53.4
# 13689                      48.8
#
# [13690 rows x 1 columns]

# %% [markdown]
# ## DataFrame Based on Movement

# %%
df_move=df.iloc[:,55:60]
df_move = df_move.fillna(0)
df_move['average movement skill']=df_move.mean(axis=1)
movement = df_move[['average movement skill']]
movement
# Out:
#        average movement skill
# 0                        91.6
# 1                        86.8
# 2                        91.0
# 3                        92.2
# 4                        79.6
# ...                       ...
# 13685                    74.6
# 13686                    68.2
# 13687                    62.8
# 13688                    66.0
# 13689                    61.2
#
# [13690 rows x 1 columns]

# %% [markdown]
# ## DataFrame Based on Power

# %%
df_power = df.iloc[:,60:65]
df_power = df_power.fillna(0)
df_power['average power skill'] = df_power.mean(axis=1)
power = df_power[['average power skill']]
power
# Out:
#        average power skill
# 0                     78.2
# 1                     89.2
# 2                     71.0
# 3                     73.0
# 4                     81.4
# ...                    ...
# 13685                 54.2
# 13686                 60.4
# 13687                 52.0
# 13688                 61.6
# 13689                 64.8
#
# [13690 rows x 1 columns]

# %% [markdown]
# ## DataFrame Based on Mental

# %%
df_mental = df.iloc[:,65:71]
df_mental = df_mental.fillna(0)
df_mental['average mental skill']=df_mental.mean(axis=1)
mental = df_mental[['average mental skill']]
mental
# Out:
#        average mental skill
# 0                 74.500000
# 1                 74.833333
# 2                 74.666667
# 3                 75.000000
# 4                 81.500000
# ...                     ...
# 13685             56.166667
# 13686             54.000000
# 13687             50.500000
# 13688             59.000000
# 13689             51.666667
#
# [13690 rows x 1 columns]

# %% [markdown]
# ## DataFrame Based on Defense

# %%
df_def =df.iloc[:,71:74]
df_def=df_def.fillna(0)
df_def['average defence skill']= df_def.mean(axis=1)
defense = df_def[['average defence skill']]
defense
# Out:
#        average defence skill
# 0                  32.000000
# 1                  28.000000
# 2                  27.333333
# 3                  27.666667
# 4                  59.000000
# ...                      ...
# 13685              46.333333
# 13686              52.333333
# 13687              54.333333
# 13688              60.000000
# 13689              56.333333
#
# [13690 rows x 1 columns]

# %% [markdown]
# ## DataFrame Based on GoalKeep

# %%
df_goalkeep =df.iloc[:,74:79]
df_goalkeep = df_goalkeep.fillna(0)
df_goalkeep['average goalkeeping skill']= df_goalkeep.mean(axis=1)
goal_keep = df_goalkeep[['average goalkeeping skill']]
goal_keep
# Out:
#        average goalkeeping skill
# 0                           10.8
# 1                           11.6
# 2                           11.8
# 3                            9.0
# 4                           11.2
# ...                          ...
# 13685                       11.6
# 13686                       14.2
# 13687                       11.0
# 13688                       12.0
# 13689                       10.4
#
# [13690 rows x 1 columns]

# %% [markdown]
# ## DataFrame Potential Position

# %%
def cleaning(x):
    if x[i]==0:
        return 0
    elif type(x[i])!= str:
        return x[i]
    else :
        return x[i].split(sep="+")[0]

# %%
df_stats = df.iloc[:,79:-1]
for i in df_stats.columns:
    df_stats[i]= df_stats.apply(lambda x:cleaning(x),axis=1)
df_stats
# Out:
#        ls  st  rs  lw  lf  cf  rf  rw lam  ... lwb ldm cdm rdm rwb  lb lcb  cb rcb
# 0      89  89  89  93  93  93  93  93  93  ...  68  66  66  66  68  63  52  52  52
# 1      91  91  91  89  90  90  90  89  88  ...  65  61  61  61  65  61  53  53  53
# 2      84  84  84  90  89  89  89  90  90  ...  66  61  61  61  66  61  46  46  46
# 3      83  83  83  89  88  88  88  89  89  ...  66  63  63  63  66  61  49  49  49
# 4      82  82  82  87  87  87  87  87  88  ...  77  77  77  77  77  73  66  66  66
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 13685  54  54  54  58  56  56  56  58  57  ...  56  53  53  53  56  55  49  49  49
# 13686  54  54  54  57  55  55  55  57  56  ...  57  54  54  54  57  56  54  54  54
# 13687  45  45  45  52  48  48  48  52  50  ...  57  56  56  56  57  57  57  57  57
# 13688  54  54  54  55  54  54  54  55  55  ...  60  59  59  59  60  61  61  61  61
# ...

# %%
df_stats['average potential skill']=df_stats.mean(axis=1) 
df_stats
# Out:
#        ls  st  rs  lw  lf  cf  ... rwb  lb lcb  cb rcb average potential skill
# 0      89  89  89  93  93  93  ...  68  63  52  52  52            3.595960e+48
# 1      91  91  91  89  90  90  ...  65  61  53  53  53            3.676768e+48
# 2      84  84  84  90  89  89  ...  66  61  46  46  46            3.393940e+48
# 3      83  83  83  89  88  88  ...  66  61  49  49  49            3.353536e+48
# 4      82  82  82  87  87  87  ...  77  73  66  66  66            3.313132e+48
# ...    ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..                     ...
# 13685  54  54  54  58  56  56  ...  56  55  49  49  49            2.181818e+48
# 13686  54  54  54  57  55  55  ...  57  56  54  54  54            2.181818e+48
# 13687  45  45  45  52  48  48  ...  57  57  57  57  57            1.818182e+48
# 13688  54  54  54  55  54  54  ...  60  61  61  61  61            2.181818e+48
# 13689  52  52  52  52  52  52  ...  57  57  57  57  57            2.101010e+48
#
# ...

# %% [markdown]
# ## Combine Each DataFrame

# %%
Final = pd.concat([physical,defense,mental,power,movement,skill,attack,general],axis=1)
Final
# Out:
#        average physical skill  ...  average general skill
# 0                   52.888889  ...              78.666667
# 1                   55.666667  ...              77.833333
# 2                   52.111111  ...              74.666667
# 3                   52.555556  ...              75.833333
# 4                   53.000000  ...              79.833333
# ...                       ...  ...                    ...
# 13685               43.444444  ...              57.500000
# 13686               44.333333  ...              57.833333
# 13687               50.625000  ...              55.500000
# 13688               49.875000  ...              59.000000
# 13689               51.000000  ...              57.666667
#
# [13690 rows x 8 columns]

# %%
Final['average physical skill'].mean()
# Out:
# 50.76896761626479

# %%
Final['average defence skill'].mean()
# Out:
# 51.62230338446561

# %%
Final['average mental skill'].mean()
# Out:
# 56.38394205015823

# %%
Final['average power skill'].mean()
# Out:
# 62.931278305332405

# %%
Final['average movement skill'].mean()
# Out:
# 66.51921110299496

# %%
Final['average controling skill'].mean()
# Out:
# 56.49006574141716

# %%
Final['average attacking skill'].mean()
# Out:
# 54.943155588020375

# %%
Final['average general skill'].mean()
# Out:
# 60.18686389091817

# %%
ss = StandardScaler()
Final2 = ss.fit_transform(Final)
df_final = pd.DataFrame(Final2,columns=Final.columns)
df_final
# Out:
#        average physical skill  ...  average general skill
# 0                    0.676633  ...               2.826824
# 1                    1.563238  ...               2.699351
# 2                    0.428383  ...               2.214951
# 3                    0.570240  ...               2.393414
# 4                    0.712097  ...               3.005287
# ...                       ...  ...                    ...
# 13685               -2.337828  ...              -0.411005
# 13686               -2.054114  ...              -0.360016
# 13687               -0.045951  ...              -0.716942
# 13688               -0.285335  ...              -0.181553
# 13689                0.073740  ...              -0.385510
#
# [13690 rows x 8 columns]

# %% [markdown]
# # KMEANS

# %%
from sklearn.cluster import KMeans
inertia = []

for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(df_final.values)
    inertia.append(kmeans.inertia_)



plt.figure(figsize=(20, 10))
# plt.plot(inertia)

sns.lineplot(x=range(2, 11), y=inertia, color='#000087', linewidth = 4)
sns.scatterplot(x=range(2, 11), y=inertia, s=300, color='#800000',  linestyle='--')

# %%
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(df_final.values)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=0, tol=0.0001, verbose=0)

# %% [markdown]
# # VISUALIZATION

# %%
from sklearn.decomposition import PCA 
pca = PCA(n_components=2)

pca.fit(df_final)
pcs = pca.transform(df_final)

data_pca = pd.DataFrame(data = pcs, columns = ['PC_1', 'PC_2'])
data_pca['clusters'] = kmeans.labels_
data_pca.head()
# Out:
#        PC_1      PC_2  clusters
# 0 -6.728781 -0.850040         2
# 1 -6.569622  0.057805         2
# 2 -5.686043 -1.268857         2
# 3 -5.694889 -1.108316         2
# 4 -6.395413  1.126537         2

# %%
fig, ax = plt.subplots(figsize=(15,10))

sns.scatterplot(
    x="PC_1", y="PC_2",
    hue="clusters",
    #edgecolor='green',
    linestyle='--',
    data=data_pca,
    palette=['blue','red','yellow','black'],
    s=160,
    ax=ax
)

# %%
from sklearn.decomposition import PCA 
pca = PCA(n_components=3)

pca.fit(df_final)
pcs = pca.transform(df_final)

data_pca = pd.DataFrame(data = pcs, columns = ['PC_1', 'PC_2','PC_3'])
data_pca['clusters'] = kmeans.labels_
data_pca.head()
# Out:
#        PC_1      PC_2      PC_3  clusters
# 0 -6.728781 -0.850040  1.491099         2
# 1 -6.569622  0.057805  2.743718         2
# 2 -5.686043 -1.268857  1.196797         2
# 3 -5.694889 -1.108316  1.231740         2
# 4 -6.395413  1.126537  0.655928         2

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt



fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111, projection='3d')

x =data_pca['PC_1']
y =data_pca['PC_2']
z =data_pca['PC_3']



ax.scatter(x, y, z, c=data_pca['clusters'], marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')


plt.show()

# %%
from sklearn.metrics import silhouette_score
for n_clusters in range (2, 11):
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(df_final)
    centers = clusterer.cluster_centers_

    score = silhouette_score(df_final, preds)
    print("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
# Out:
# For n_clusters = 2, silhouette score is 0.2935633930075519)
# For n_clusters = 3, silhouette score is 0.21118125810364013)
# For n_clusters = 4, silhouette score is 0.21367953400948755)
# For n_clusters = 5, silhouette score is 0.21401473395215)
# For n_clusters = 6, silhouette score is 0.21216728493740775)
# For n_clusters = 7, silhouette score is 0.19649259970936944)
# For n_clusters = 8, silhouette score is 0.19668449466962065)
# For n_clusters = 9, silhouette score is 0.19659592621045938)
# For n_clusters = 10, silhouette score is 0.19744383086100775)

# %%
df['cluster']=kmeans.labels_

# %%
df.head()
# Out:
#    Unnamed: 0  sofifa_id  ...    rb cluster
# 0           0     158023  ...  63+2       2
# 1           1      20801  ...  61+3       2
# 2           2     190871  ...  61+3       2
# 3           4     183277  ...  61+3       2
# 4           5     192985  ...  73+3       2
#
# [5 rows x 106 columns]

# %% [markdown]
# ## Cluster 0

# %%
df0 = df[df['cluster']==0]

# %%
df0.head()
# Out:
#      Unnamed: 0  sofifa_id  ...    rb cluster
# 345         407     190547  ...  66+3       0
# 516         590     219145  ...  65+2       0
# 605         686     202054  ...  65+2       0
# 651         736     220570  ...  69+2       0
# 685         772     219258  ...  66+2       0
#
# [5 rows x 106 columns]

# %%
df0['value_eur'].mean()
# Out:
# 603356.7003586567

# %%
df0['overall'].mean()
# Out:
# 61.42093250733616

# %%
df0.shape
# Out:
# (3067, 106)

# %% [markdown]
# ## Cluster 1

# %%
df1 = df[df['cluster']==1]

# %%
df1.head()
# Out:
#      Unnamed: 0  sofifa_id  ...    rb cluster
# 550         627     220131  ...  49+2       1
# 611         692     205850  ...  47+2       1
# 627         710     243238  ...  48+2       1
# 679         765     198719  ...  52+2       1
# 703         794     224933  ...  51+2       1
#
# [5 rows x 106 columns]

# %%
df1['value_eur'].mean()
# Out:
# 1340947.638019351

# %%
df1['overall'].mean()
# Out:
# 65.98093340922026

# %%
df1.shape
# Out:
# (3514, 106)

# %% [markdown]
# ## Cluster 2

# %%
df2 = df[df['cluster']==2]

# %%
df2.head()
# Out:
#    Unnamed: 0  sofifa_id  ...    rb cluster
# 0           0     158023  ...  63+2       2
# 1           1      20801  ...  61+3       2
# 2           2     190871  ...  61+3       2
# 3           4     183277  ...  61+3       2
# 4           5     192985  ...  73+3       2
#
# [5 rows x 106 columns]

# %%
df2['value_eur'].mean()
# Out:
# 7606780.495079034

# %%
df2['overall'].mean()
# Out:
# 74.001192961527

# %%
df2.shape
# Out:
# (3353, 106)

# %% [markdown]
# ## Cluster 3

# %%
df3 = df[df['cluster']==3]

# %%
df3.head()
# Out:
#     Unnamed: 0  sofifa_id  ...    rb cluster
# 9           11     201024  ...  77+3       3
# 12          16     138956  ...  76+3       3
# 45          54     232363  ...  76+2       3
# 58          69     201535  ...  77+3       3
# 59          70     212190  ...  75+2       3
#
# [5 rows x 106 columns]

# %%
df3['value_eur'].mean()
# Out:
# 1938214.856230032

# %%
df3['overall'].mean()
# Out:
# 67.54286474973377

# %%
df3.shape
# Out:
# (3756, 106)
