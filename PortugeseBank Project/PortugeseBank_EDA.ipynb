# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## Author
#
#
#
# 1.   Muhammad Dhiaz Rafilianza **(First Author)**
# 2.   Daniel Najoan **(Second Author)**
# 3.   Ghazali Akmal Rabbani **(Third Author)**

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Data Extraction

# %%
df = pd.read_csv('bank-full.csv',sep=';')
df.head()
# Out:
#    age           job  marital  education  ... pdays  previous poutcome   y
# 0   58    management  married   tertiary  ...    -1         0  unknown  no
# 1   44    technician   single  secondary  ...    -1         0  unknown  no
# 2   33  entrepreneur  married  secondary  ...    -1         0  unknown  no
# 3   47   blue-collar  married    unknown  ...    -1         0  unknown  no
# 4   33       unknown   single    unknown  ...    -1         0  unknown  no
#
# [5 rows x 17 columns]

# %% [markdown]
# ## 2. EDA

# %% [markdown]
# ### Summary Statistical Analysis

# %% [markdown]
# ##### Information Analysis

# %% [markdown]
# Summary information of each column in dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# Based on the summary information in the above, there are **7 columns with integer type(int64)** which denotes **Numerical Column** and **10 columns with object type** which denotes **Categorical Column** .  And also there are **45211 data**

# %% [markdown]
# **Check for Missing Value**

# %% [markdown]
# There are no missing value in this dataset

# %%
df.notnull().all().all()
# Out:
# True

# %% [markdown]
# ##### **Statistical Numerical Analysis**

# %%
df.describe()
# Out:
#                 age        balance  ...         pdays      previous
# count  45211.000000   45211.000000  ...  45211.000000  45211.000000
# mean      40.936210    1362.272058  ...     40.197828      0.580323
# std       10.618762    3044.765829  ...    100.128746      2.303441
# min       18.000000   -8019.000000  ...     -1.000000      0.000000
# 25%       33.000000      72.000000  ...     -1.000000      0.000000
# 50%       39.000000     448.000000  ...     -1.000000      0.000000
# 75%       48.000000    1428.000000  ...     -1.000000      0.000000
# max       95.000000  102127.000000  ...    871.000000    275.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# *   **Count** is a total data of each column
# *   **Mean** is an average of all the numbers
# *   **std** or Standard Deviation is measurement to tell how a set of values spread out from their mean. A low Standard Deviation whows that the values are close to the mean and a high Standard Deviation shows a high diversion from the mean

# %% [markdown]
# ##### **Statistical Categorical Analysis**

# %% [markdown]
# Create a list of categorical column and pass the value to **dfcat** variable

# %%
dfcat=df.select_dtypes(include=['object']).columns.tolist()
dfcat
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'y']

# %% [markdown]
# Indexing and selecting column with categorical value from main dataframe. And pass the value to **dfcategorical** variable

# %%
dfcategorical = df[dfcat]
dfcategorical.head()
# Out:
#             job  marital  education default  ...  contact month poutcome   y
# 0    management  married   tertiary      no  ...  unknown   may  unknown  no
# 1    technician   single  secondary      no  ...  unknown   may  unknown  no
# 2  entrepreneur  married  secondary      no  ...  unknown   may  unknown  no
# 3   blue-collar  married    unknown      no  ...  unknown   may  unknown  no
# 4       unknown   single    unknown      no  ...  unknown   may  unknown  no
#
# [5 rows x 10 columns]

# %% [markdown]
# The result of categorical analysis from each categorical column in dataframe

# %%
dfcategorical.describe()
# Out:
#                 job  marital  education  ...  month poutcome      y
# count         45211    45211      45211  ...  45211    45211  45211
# unique           12        3          4  ...     12        4      2
# top     blue-collar  married  secondary  ...    may  unknown     no
# freq           9732    27214      23202  ...  13766    36959  39922
#
# [4 rows x 10 columns]

# %% [markdown]
# *   **count** is total data of each column
# *   **unique** is total of unique data in each column. For example, in Job column there are 12 difference kind of data
# *   **top** is the most frequency or mode data in each column
# *   **freq** is total of top data or mode data in each column. For example, in Job column, the mode data is *blue-collar* and total of data with value of *blue-collar* is 9732 data in Job column

# %% [markdown]
# ### Univariate Analysis

# %%
# Separate Which is Categorical and Numerical
Num = ['age','balance','day','duration','campaign','pdays','previous']
Cat =[]
for i in list(df.columns):
    if i in (Num +['y']):
        continue
    else:
        Cat.append(i)

# %% [markdown]
# #### Boxplot

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(df[Num[0]]).set_title('Age')
# Out:
# Text(0.5, 1.0, 'Age')

# %%
print ('Median : ', df[Num[0]].median())
print ('1st Quartile : ', df[Num[0]].quantile(0.25))
print ('3rd Quartile : ', df[Num[0]].quantile(0.75))
print ('IQR : ', scipy.stats.iqr(df[Num[0]]))
print ('Outlier : YES')
# Out:
# Median :  39.0
# 1st Quartile :  33.0
# 3rd Quartile :  48.0
# IQR :  15.0
# Outlier : YES

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(df[Num[1]]).set_title('Balance')
# Out:
# Text(0.5, 1.0, 'Balance')

# %%
print ('Median : ', df[Num[1]].median())
print ('1st Quartile : ', df[Num[1]].quantile(0.25))
print ('3rd Quartile : ', df[Num[1]].quantile(0.75))
print ('IQR : ', scipy.stats.iqr(df[Num[1]]))
print ('Outlier : YES')
# Out:
# Median :  448.0
# 1st Quartile :  72.0
# 3rd Quartile :  1428.0
# IQR :  1356.0
# Outlier : YES

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(df[Num[2]]).set_title('Day')
# Out:
# Text(0.5, 1.0, 'Day')

# %%
print ('Median : ', df[Num[2]].median())
print ('1st Quartile : ', df[Num[2]].quantile(0.25))
print ('3rd Quartile : ', df[Num[2]].quantile(0.75))
print ('IQR : ', scipy.stats.iqr(df[Num[2]]))
print ('Outlier : NO')
# Out:
# Median :  16.0
# 1st Quartile :  8.0
# 3rd Quartile :  21.0
# IQR :  13.0
# Outlier : NO

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(df[Num[3]]).set_title('Duration')
# Out:
# Text(0.5, 1.0, 'Duration')

# %%
print ('Median : ', df[Num[3]].median())
print ('1st Quartile : ', df[Num[3]].quantile(0.25))
print ('3rd Quartile : ', df[Num[3]].quantile(0.75))
print ('IQR : ', scipy.stats.iqr(df[Num[3]]))
print ('Outlier : YES')
# Out:
# Median :  180.0
# 1st Quartile :  103.0
# 3rd Quartile :  319.0
# IQR :  216.0
# Outlier : YES

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(df[Num[4]]).set_title('Campaign')
# Out:
# Text(0.5, 1.0, 'Campaign')

# %%
print ('Median : ', df[Num[4]].median())
print ('1st Quartile : ', df[Num[4]].quantile(0.25))
print ('3rd Quartile : ', df[Num[4]].quantile(0.75))
print ('IQR : ', scipy.stats.iqr(df[Num[4]]))
print ('Outlier : YES')
# Out:
# Median :  2.0
# 1st Quartile :  1.0
# 3rd Quartile :  3.0
# IQR :  2.0
# Outlier : YES

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(df[Num[5]]).set_title('pdays')
# Out:
# Text(0.5, 1.0, 'pdays')

# %%
print ('Median : ', df[Num[5]].median())
print ('1st Quartile : ', df[Num[5]].quantile(0.25))
print ('3rd Quartile : ', df[Num[5]].quantile(0.75))
print ('IQR : ', scipy.stats.iqr(df[Num[5]]))
print ('Outlier : YES')
# Out:
# Median :  -1.0
# 1st Quartile :  -1.0
# 3rd Quartile :  -1.0
# IQR :  0.0
# Outlier : YES

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(df[Num[6]]).set_title('Previous')
# Out:
# Text(0.5, 1.0, 'Previous')

# %%
print ('Median : ', df[Num[6]].median())
print ('1st Quartile : ', df[Num[6]].quantile(0.25))
print ('3rd Quartile : ', df[Num[6]].quantile(0.75))
print ('IQR : ', scipy.stats.iqr(df[Num[6]]))
print ('Outlier : YES')
# Out:
# Median :  0.0
# 1st Quartile :  0.0
# 3rd Quartile :  0.0
# IQR :  0.0
# Outlier : YES

# %% [markdown]
# #### Target Analysis

# %%
yesOrno = ["No","Yes"]
totalDataYesOrNo = df['y'].value_counts()
initialize = pd.DataFrame({'Target':yesOrno, 'Total':totalDataYesOrNo})
initialize
# Out:
#     Target  Total
# no      No  39922
# yes    Yes   5289

# %%
# ini = pd.DataFrame(['No','Yes'],columns=['Target'])
# ini['Jumlah']= df['y'].value_counts()
# ini

plt.figure(figsize = (10, 8))
ax = sns.barplot(
    x = initialize['Target'],
    y = initialize['Total'],
    data = initialize,
)

plt.title('Target Count', fontsize = 18, fontweight = 'bold')
plt.xlabel('Labels', fontsize = 15, fontweight = 'bold')
plt.ylabel('# In Label', fontsize = 15, fontweight = 'bold')


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# Imbalanced Dataset. Resampling is needed to become balanced

# %% [markdown]
# #### Visualization Numerical Analysis

# %%
Num
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %% [markdown]
# ##### Age Analysis

# %%
Num_2 = df[Num[0]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight2 = ['red' if (x == Num_2['counts'].max()) else 'lightgrey' for x in Num_2['counts']]


plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Num_2,
    palette = highlight2,
    order=Num_2.sort_values('counts',ascending=False).unique_values
)

plt.title('Age Analysis', fontsize = 18, fontweight = 'bold')
plt.xlabel('Age', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Balance Analysis

# %%
Num_2 = df[Num[1]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight2 = ['red' if (x == Num_2['counts'].max()) else 'lightgrey' for x in Num_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Num_2,
    palette = highlight2,
    order=Num_2.sort_values('counts',ascending=False).unique_values
)

plt.title('Balance Analysis', fontsize = 18, fontweight = 'bold')
plt.xlabel('Balance', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %%
df[Num[1]].value_counts().rename_axis('unique_values').reset_index(name='counts')
# Out:
#       unique_values  counts
# 0                 0    3514
# 1                 1     195
# 2                 2     156
# 3                 4     139
# 4                 3     134
# ...             ...     ...
# 7163           4305       1
# 7164           6352       1
# 7165          18881       1
# 7166          14889       1
# 7167           7218       1
#
# [7168 rows x 2 columns]

# %% [markdown]
# ##### Day Analysis

# %%
Num_2 = df[Num[2]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight2 = ['red' if (x == Num_2['counts'].max()) else 'lightgrey' for x in Num_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Num_2,
    palette = highlight2,
    order=Num_2.sort_values('counts',ascending=False).unique_values
)

plt.title('Day Analysis', fontsize = 18, fontweight = 'bold')
plt.xlabel('Day', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Duration Analysis

# %%
Num_2 = df[Num[3]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight2 = ['red' if (x == Num_2['counts'].max()) else 'lightgrey' for x in Num_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Num_2,
    palette = highlight2,
    order=Num_2.sort_values('counts',ascending=False).unique_values
)

plt.title('Duration Analysis', fontsize = 18, fontweight = 'bold')
plt.xlabel('Duration', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %%
df[Num[3]].value_counts().rename_axis('unique_values').reset_index(name='counts')
# Out:
#       unique_values  counts
# 0               124     188
# 1                90     184
# 2                89     177
# 3               122     175
# 4               104     175
# ...             ...     ...
# 1568           2150       1
# 1569           1970       1
# 1570           1906       1
# 1571           1842       1
# 1572           2015       1
#
# [1573 rows x 2 columns]

# %% [markdown]
# ##### Campaign Analysis

# %%
Num_2 = df[Num[4]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight2 = ['red' if (x == Num_2['counts'].max()) else 'lightgrey' for x in Num_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Num_2,
    palette = highlight2,
    order=Num_2.sort_values('counts',ascending=False).unique_values
)

plt.title('Campaign Analysis', fontsize = 18, fontweight = 'bold')
plt.xlabel('Campaign', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### pdays Analysis

# %%
Num_2 = df[Num[5]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight2 = ['red' if (x == Num_2['counts'].max()) else 'lightgrey' for x in Num_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Num_2,
    palette = highlight2,
    order=Num_2.sort_values('counts',ascending=False).unique_values
)

plt.title('pdays Analysis', fontsize = 18, fontweight = 'bold')
plt.xlabel('pdays', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %%
df[Num[5]].value_counts().rename_axis('unique_values').reset_index(name='counts')
# Out:
#      unique_values  counts
# 0               -1   36954
# 1              182     167
# 2               92     147
# 3              183     126
# 4               91     126
# ..             ...     ...
# 554            749       1
# 555            717       1
# 556            589       1
# 557            493       1
# 558             32       1
#
# [559 rows x 2 columns]

# %% [markdown]
# ##### previous Analysis

# %%
Num_2 = df[Num[6]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight2 = ['red' if (x == Num_2['counts'].max()) else 'lightgrey' for x in Num_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Num_2,
    palette = highlight2,
    order=Num_2.sort_values('counts',ascending=False).unique_values
)

plt.title('previous Analysis', fontsize = 18, fontweight = 'bold')
plt.xlabel('previous', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# #### Visualization Categorical Analysis

# %%
Cat
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome']

# %% [markdown]
# ##### Job Analysis

# %%
Cat_2 = df[Cat[0]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight3 = ['red' if (x == Cat_2['counts'].max()) else 'lightgrey' for x in Cat_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Cat_2,
    palette = highlight3
)

plt.title('Job Count', fontsize = 18, fontweight = 'bold')
plt.xlabel('Jobs', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Marital Status Analysis

# %%
Cat_2 = df[Cat[1]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight3 = ['red' if (x == Cat_2['counts'].max()) else 'lightgrey' for x in Cat_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Cat_2,
    palette = highlight3
)

plt.title('Marital Status Count', fontsize = 18, fontweight = 'bold')
plt.xlabel('Marital Status', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Education Analysis

# %%
Cat_2 = df[Cat[2]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight3 = ['red' if (x == Cat_2['counts'].max()) else 'lightgrey' for x in Cat_2['counts']]
plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Cat_2,
    palette = highlight3
)

plt.title('Education Count', fontsize = 18, fontweight = 'bold')
plt.xlabel('Education', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Default Analysis

# %%
Cat_2 = df[Cat[3]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight3 = ['red' if (x == Cat_2['counts'].max()) else 'lightgrey' for x in Cat_2['counts']]
plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Cat_2,
    palette = highlight3
)

plt.title('Default Count ', fontsize = 18, fontweight = 'bold')
plt.xlabel('Default ', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Housing Analysis

# %%
Cat_2 = df[Cat[4]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight3 = ['red' if (x == Cat_2['counts'].max()) else 'lightgrey' for x in Cat_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Cat_2,
    palette = highlight3
)

plt.title('Housing Count ', fontsize = 18, fontweight = 'bold')
plt.xlabel('Housing', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Loan Analysis

# %%
Cat_2 = df[Cat[5]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight3 = ['red' if (x == Cat_2['counts'].max()) else 'lightgrey' for x in Cat_2['counts']]

plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Cat_2,
    palette = highlight3
)

plt.title('Loan Count ', fontsize = 18, fontweight = 'bold')
plt.xlabel('Loan', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Contact Analysis

# %%
Cat_2 = df[Cat[6]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight3 = ['red' if (x == Cat_2['counts'].max()) else 'lightgrey' for x in Cat_2['counts']]
plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Cat_2,
    palette = highlight3
)

plt.title('Contact Count ', fontsize = 18, fontweight = 'bold')
plt.xlabel('Contact', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Month Analysis

# %%
Cat_2 = df[Cat[7]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight3 = ['red' if (x == Cat_2['counts'].max()) else 'lightgrey' for x in Cat_2['counts']]
plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Cat_2,
    palette = highlight3
)

plt.title('Month Count ', fontsize = 18, fontweight = 'bold')
plt.xlabel('Months', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ##### Poutcome Analysis

# %%
Cat_2 = df[Cat[8]].value_counts().rename_axis('unique_values').reset_index(name='counts')
highlight3 = ['red' if (x == Cat_2['counts'].max()) else 'lightgrey' for x in Cat_2['counts']]
plt.figure(figsize = (15, 8))
ax = sns.barplot(
    x = 'unique_values',
    y = 'counts',
    data = Cat_2,
    palette = highlight3
)

plt.title('Poutcome Count ', fontsize = 18, fontweight = 'bold')
plt.xlabel('Poutcome', fontsize = 15, fontweight = 'bold')
plt.ylabel('Total', fontsize = 15, fontweight = 'bold')
plt.tight_layout()


for x in ax.patches:
    ax.annotate(
            format(x.get_height(), '.0f'),
            (x.get_x() + x.get_width() / 2., x.get_height()), 
            ha = 'center',
            va = 'center',
            fontweight = 'bold',
            size = 13,
            xytext = (0, 7), 
            textcoords = 'offset points'
    )

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Plot all Numerical Feature with Target

# %%
# All Numerical Value with Target

fig,ax = plt.subplots(len(Num),1,figsize=(10,15))
for i in range (0,len(Num)):
    sns.catplot(data = df ,x=df['y'],y=df[Num[i]],ax=ax[i])

# %% [markdown]
# Noteable Differences :
# <br>
# - Campaign No > Campaign Yes
# - Balance No > Balance Yes
# - pdays Yes > pdays No

# %% [markdown]
# ### Multivariate Analysis

# %%
df['y']=np.where(df['y']=='yes',1,0)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df.job = le.fit_transform(df.job)
df.marital = le.fit_transform(df.marital)
df.education = le.fit_transform(df.education)
df.default = le.fit_transform(df.default)
df.housing = le.fit_transform(df.housing)
df.loan = le.fit_transform(df.loan)
df.contact = le.fit_transform(df.contact)
df.month = le.fit_transform(df.month)
df.poutcome = le.fit_transform(df.poutcome)

# %%
df.head()
# Out:
#        age  job  marital  education  ...  pdays  previous  poutcome  y
# 45206   51    9        1          2  ...     -1         0         3  1
# 45207   71    5        0          0  ...     -1         0         3  1
# 45208   72    5        1          1  ...    184         3         2  1
# 45209   57    1        1          1  ...     -1         0         3  0
# 45210   37    2        1          1  ...    188        11         1  0
#
# [5 rows x 17 columns]

# %% [markdown]
# #### Correlation Heatmap

# %%
# Increase the size of the heatmap.
plt.figure(figsize=(16, 6))

# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)

# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# - Duration has the strongest Linear Correlation Between feature and target
# - No features seems to be redundant

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(df)
